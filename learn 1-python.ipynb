# %% [markdown]
# <a href="https://colab.research.google.com/github/lutfi0404/C-fundamental/blob/main/learn%201-python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# materi pertama pembelajaran tentang pyhon

# %%
a=2
b=3
c=a+b

print (c)
# Out:
# 5
